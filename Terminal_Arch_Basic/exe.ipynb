# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd//content/drive/MyDrive/Colab_Notebooks/deeplearningbro/pytorch/cifar10
# Out:
# /content/drive/MyDrive/Colab_Notebooks/deeplearningbro/pytorch/cifar10

# %%
# !python main.py

# %%
# 변수를 컨트롤 할 때는 --변수 파라미터
# !python main.py --train eval --pretrained ./results/resnet18_best.pth
# Out:
# Namespace(batch_size=128, epoch=101, l2=0.0001, lr=0.001, model_name='resnet18', pretrained='./results/resnet18_best.pth', train='eval')
# Traceback (most recent call last):
#   File "main.py", line 33, in <module>
#     trainloader, testloader = datasets.dataloader(args.batch_size, 'eval')
#   File "/content/drive/MyDrive/Colab_Notebooks/deeplearningbro/pytorch/cifar10/datasets.py", line 17, in dataloader
#     trainset = torchvision.datasets.CIFAR10(root='./data', download=True, train=True, transform=test_transf)
#   File "/usr/local/lib/python3.7/dist-packages/torchvision/datasets/cifar.py", line 66, in __init__
#     self.download()
#   File "/usr/local/lib/python3.7/dist-packages/torchvision/datasets/cifar.py", line 144, in download
#     download_and_extract_archive(self.url, self.root, filename=self.filename, md5=self.tgz_md5)
#   File "/usr/local/lib/python3.7/dist-packages/torchvision/datasets/utils.py", line 427, in download_and_extract_archive
# ...
